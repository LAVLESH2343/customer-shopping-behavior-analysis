# %%
import pandas as pd
from matplotlib import pyplot as plt 
df = pd.read_csv("ba.csv")
df.columns.tolist()

# %%
df.head(21)

# %%
df[['fraud_flag','authentication_type']].head(21)
df.info()

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()

# %%
df[['fraud_flag','anomaly_score']]

# %%
df['fraud_flag'].value_counts(normalize=True) * 100

# %%
tasks = [[1,2],[2,4],[4,8]]
tasks.sort(key=lambda x: x[1]-x[0])
print(tasks)
# Out:
# [[1, 2], [2, 4], [4, 8]]
